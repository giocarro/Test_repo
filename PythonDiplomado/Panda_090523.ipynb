# %% [markdown]
# <a href="https://colab.research.google.com/github/giocarro/Test_repo/blob/main/PythonDiplomado/Panda_090523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.DataFrame().dtypes
# Out:
# Series([], dtype: object)

# %%
data = [1,2,3,4,5]

# %%
pd.DataFrame(data)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
pd.DataFrame(data, columns = ['Numeros'])
# Out:
#    Numeros
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
pd.DataFrame(data, columns = ['Numeros'], index = ['Lun','Mar','Mier','Juev','Vier'])
# Out:
#       Numeros
# Lun         1
# Mar         2
# Mier        3
# Juev        4
# Vier        5

# %%
data = [['Juan',20],['Luisa',30], ['Ricardo',25]]
pd.DataFrame(data,columns = ['Nombre','Edad'])
# Out:
#     Nombre  Edad
# 0     Juan    20
# 1    Luisa    30
# 2  Ricardo    25

# %%
data = {''}

# %%
pd.read_excel('/content/tote_shipment.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e14fe453a0b5> in <cell line: 1>()
# ----> 1 pd.read_excel('/content/tote_shipment.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     488
#     489     try:
# --> 490         data = io.parse(
#     491             sheet_name=sheet_name,
#     492             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1732             DataFrame from the passed in Excel file.
#    1733         """
# -> 1734         return self._reader.parse(
#    1735             sheet_name=sheet_name,
#    1736             header=header,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     763
#     764             file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 765             data = self.get_sheet_data(sheet, convert_float, file_rows_needed)
#     766             if hasattr(sheet, "close"):
#     767                 # pyxlsb opens two TemporaryFiles
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in get_sheet_data(self, sheet, convert_float, file_rows_needed)
#     613         data: list[list[Scalar]] = []
#     614         last_row_with_data = -1
# --> 615         for row_number, row in enumerate(sheet.rows):
#     616             converted_row = [self._convert_cell(cell, convert_float) for cell in row]
#     617             while converted_row and converted_row[-1] == "":
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_read_only.py in _cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77                                  data_only=self.parent.data_only, epoch=self.parent.epoch,
#      78                                  date_formats=self.parent._date_formats)
# ---> 79         for idx, row in parser.parse():
#      80             if max_row is not None and idx > max_row:
#      81                 break
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py in parse(self)
#     142         it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
#     143
# --> 144         for _, element in it:
#     145             tag_name = element.tag
#     146             if tag_name in dispatcher:
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in iterator(source)
#    1256                 if not data:
#    1257                     break
# -> 1258                 pullparser.feed(data)
#    1259             root = pullparser._close_and_return_root()
#    1260             yield from pullparser.read_events()
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in feed(self, data)
#    1294         if data:
#    1295             try:
# -> 1296                 self._parser.feed(data)
#    1297             except SyntaxError as exc:
#    1298                 self._events_queue.append(exc)
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in feed(self, data)
#    1711         """Feed encoded data to parser."""
#    1712         try:
# -> 1713             self.parser.Parse(data, False)
#    1714         except self._error as v:
#    1715             self._raiseerror(v)
#
# ../Modules/pyexpat.c in EndElement()
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in handler(tag, event, append, end)
#    1580                 parser.StartElementHandler = handler
#    1581             elif event_name == "end":
# -> 1582                 def handler(tag, event=event_name, append=append,
#    1583                             end=self._end):
#    1584                     append((event, end(tag)))
#
# KeyboardInterrupt:

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
df = pd.read_excel('tote_shipment.xlsx')

# %%
df.head(10)
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
# 5       tote         2  (01)00850027865010(21)0082T0219  DC 2  dock_doors_DC2
# 6       tote         2  (01)00850027865010(21)0082T0219  DC 2  dock_doors_DC2
# 7       tote         2  (01)00850027865010(21)0082T0670  DC 2  dock_doors_DC2
# 8       tote         2  (01)00850027865010(21)0082T0670  DC 2  dock_doors_DC2
# 9       tote         2  (01)00850027865010(21)0082T0670  DC 2  dock_doors_DC2
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
# 5  379663A695EF 2022-08-03 13:22:09.038  47.79366 -65.75921           25.0
# 6  379663A695EF 2022-08-03 13:26:07.080  47.79366 -65.75921           25.0
# 7  379663A695EF 2022-08-03 10:59:28.892  47.79366 -65.75921           24.5
# 8  2FC8DD79125D 2022-08-03 12:48:11.580  47.79366 -65.75921           25.0
# 9  2FC8DD79125D 2022-08-03 13:02:29.755  47.79366 -65.75921           25.0
#
#    Temperature_F
# 0           73.4
# 1           73.4
# 2           73.4
# 3           74.3
# 4           73.4
# 5           77.0
# 6           77.0
# 7           76.1
# 8           77.0
# 9           77.0

# %%
df.tail()
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 130056  store_front_Store  26AB1C9A2E41 2022-08-04 12:48:51.273  47.74923
# 130057  store_front_Store  26AB1C9A2E41 2022-08-04 12:49:58.699  47.74923
# 130058  store_front_Store  26AB1C9A2E41 2022-08-04 12:52:45.173  47.74923
# 130059  store_front_Store  26AB1C9A2E41 2022-08-04 12:53:48.228  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C  Temperature_F
# 130056 -65.64101           23.1          73.58
# 130057 -65.64101           23.5          74.30
# 130058 -65.64101           23.0          73.40
# 130059 -65.64101           23.0          73.40
# 130060 -65.64101           24.0          75.20

# %%
df_1 = pd.read_excel('tote_shipment.xlsx',header = None)
df_1.head()
# Out:
#            0         1                                2     3   \
# 0  asset_type  asset_id                           tag_id  Site
# 1        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 2        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 3        tote         2  (01)00850027865010(21)0082T0219  DC 1
# 4        tote         2  (01)00850027865010(21)0082T0219  DC 1
#
#                4             5                           6         7   \
# 0            Zone     device_id                    time_est       lat
# 1  dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2  dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3  dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4  dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
#
#          8              9              10
# 0       lng  Temperature_C  Temperature_F
# 1 -65.68902             23           73.4
# 2 -65.68902             23           73.4
# 3 -65.68902             23           73.4
# 4 -65.68902           23.5           74.3

# %%
df_1.columns = ['Tipo','Asset ID','Tag ID','Sitio','Zona','Device ID','Tiempo','lat','Ing','Temp_C','Temp_F']
df_1
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio  \
# 0       asset_type  asset_id                           tag_id   Site
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1
# ...            ...       ...                              ...    ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zona     Device ID                      Tiempo       lat  \
# 0                    Zone     device_id                    time_est       lat
# 1          dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2          dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3          dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4          dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
# ...                   ...           ...                         ...       ...
# 130057  store_front_Store  26AB1C9A2E41  2022-08-04 12:48:51.273000  47.74923
# 130058  store_front_Store  26AB1C9A2E41  2022-08-04 12:49:58.699000  47.74923
# 130059  store_front_Store  26AB1C9A2E41  2022-08-04 12:52:45.173000  47.74923
# 130060  store_front_Store  26AB1C9A2E41  2022-08-04 12:53:48.228000  47.74923
# 130061  store_front_Store  26AB1C9A2E41  2022-08-04 16:33:25.525000  47.74923
#
#              Ing         Temp_C         Temp_F
# 0            lng  Temperature_C  Temperature_F
# 1      -65.68902             23           73.4
# 2      -65.68902             23           73.4
# 3      -65.68902             23           73.4
# 4      -65.68902           23.5           74.3
# ...          ...            ...            ...
# 130057 -65.64101           23.1          73.58
# 130058 -65.64101           23.5           74.3
# 130059 -65.64101             23           73.4
# 130060 -65.64101             23           73.4
# 130061 -65.64101             24           75.2
#
# [130062 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['asset_type', 'asset_id', 'tag_id', 'Site', 'Zone', 'device_id',
#        'time_est', 'lat', 'lng', 'Temperature_C', 'Temperature_F'],
#       dtype='object')

# %%
df = df.rename(columns = {'asset_type':'tipo', 'Site':'Sitio', 'Zone':'zona', 'time_est':'hora'})
df.head()
# Out:
#    tipo  asset_id                           tag_id Sitio            zona  \
# 0  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3  tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4  tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                    hora       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# 1           73.4
# 2           73.4
# 3           74.3
# 4           73.4

# %%
df.shape
# Out:
# (130061, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tipo           130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Sitio          130061 non-null  object
#  4   zona           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   hora           130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 10.9+ MB

# %%
df.describe()
# Out:
#             asset_id            lat            lng  Temperature_C  \
# count  130061.000000  130061.000000  130061.000000  130061.000000
# mean      105.184475      47.760258     -65.668955      25.874445
# std        61.459262       0.019223       0.049597       2.795208
# min         2.000000      47.748780     -65.762200      19.000000
# 25%        58.000000      47.749230     -65.641010      24.000000
# 50%        84.000000      47.749230     -65.641010      25.000000
# 75%       167.000000      47.749388     -65.641010      27.500000
# max       205.000000      47.805010     -65.640330      44.000000
#
#        Temperature_F
# count  130061.000000
# mean       78.574000
# std         5.031375
# min        66.200000
# 25%        75.200000
# 50%        77.000000
# 75%        81.500000
# max       111.200000

# %%
df.describe(include = 'all')
# Out:
# <ipython-input-26-74aa2f970831>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all')
#           tipo       asset_id                           tag_id   Sitio  \
# count   130061  130061.000000                           130061  130061
# unique       1            NaN                               34       4
# top       tote            NaN  (01)00850027865010(21)0082T0953   Store
# freq    130061            NaN                             6602   96897
# first      NaN            NaN                              NaN     NaN
# last       NaN            NaN                              NaN     NaN
# mean       NaN     105.184475                              NaN     NaN
# std        NaN      61.459262                              NaN     NaN
# min        NaN       2.000000                              NaN     NaN
# 25%        NaN      58.000000                              NaN     NaN
# 50%        NaN      84.000000                              NaN     NaN
# 75%        NaN     167.000000                              NaN     NaN
# max        NaN     205.000000                              NaN     NaN
#
#                    zona     device_id                        hora  \
# count            130061        130061                      130061
# unique               15            38                      129887
# top     receiving_Store  AC8DEAE6FD79  2022-08-05 01:04:26.437000
# freq              66099         43611                           2
# first               NaN           NaN  2022-08-02 10:14:54.326000
# last                NaN           NaN  2022-08-05 13:28:29.966000
# mean                NaN           NaN                         NaN
# std                 NaN           NaN                         NaN
# min                 NaN           NaN                         NaN
# 25%                 NaN           NaN                         NaN
# 50%                 NaN           NaN                         NaN
# 75%                 NaN           NaN                         NaN
# max                 NaN           NaN                         NaN
#
#                   lat            lng  Temperature_C  Temperature_F
# count   130061.000000  130061.000000  130061.000000  130061.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# first             NaN            NaN            NaN            NaN
# last              NaN            NaN            NaN            NaN
# mean        47.760258     -65.668955      25.874445      78.574000
# std          0.019223       0.049597       2.795208       5.031375
# min         47.748780     -65.762200      19.000000      66.200000
# 25%         47.749230     -65.641010      24.000000      75.200000
# 50%         47.749230     -65.641010      25.000000      77.000000
# 75%         47.749388     -65.641010      27.500000      81.500000
# max         47.805010     -65.640330      44.000000     111.200000

# %%
df['asset_id']
# Out:
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2
#          ...
# 130056    205
# 130057    205
# 130058    205
# 130059    205
# 130060    205
# Name: asset_id, Length: 130061, dtype: int64

# %%
df[['asset_id','tag_id']]
# Out:
#         asset_id                           tag_id
# 0              2  (01)00850027865010(21)0082T0219
# 1              2  (01)00850027865010(21)0082T0219
# 2              2  (01)00850027865010(21)0082T0219
# 3              2  (01)00850027865010(21)0082T0219
# 4              2  (01)00850027865010(21)0082T0670
# ...          ...                              ...
# 130056       205  (01)00850027865010(21)0082T1137
# 130057       205  (01)00850027865010(21)0082T1137
# 130058       205  (01)00850027865010(21)0082T1137
# 130059       205  (01)00850027865010(21)0082T1137
# 130060       205  (01)00850027865010(21)0082T1137
#
# [130061 rows x 2 columns]

# %%
df['asset_id'].unique()
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
len(df['asset_id'].unique())
# Out:
# 18

# %%
df['asset_id'].nunique()
# Out:
# 18

# %%
df.asset_id.unique()
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
df.tag_id.unique()
# Out:
# array(['(01)00850027865010(21)0082T0219',
#        '(01)00850027865010(21)0082T0670',
#        '(01)00850027865010(21)0082T0017',
#        '(01)00850027865010(21)0082T0953',
#        '(01)00850027865010(21)0082T0685',
#        '(01)00850027865010(21)0082T1101',
#        '(01)00850027865010(21)0082T0040',
#        '(01)00850027865010(21)0082T0495',
#        '(01)00850027865010(21)0082T0485',
#        '(01)00850027865010(21)0082T0525',
#        '(01)00850027865010(21)0082T0193',
#        '(01)00850027865010(21)0082T0194',
#        '(01)00850027865010(21)0082T0415',
#        '(01)00850027865010(21)0082T1188',
#        '(01)00850027865010(21)0082T0117',
#        '(01)00850027865010(21)0082T0932',
#        '(01)00850027865010(21)0082T0329',
#        '(01)00850027865010(21)0082T0458',
#        '(01)00850027865010(21)0082T0609',
#        '(01)00850027865010(21)0082T0260',
#        '(01)00850027865010(21)0082T0261',
#        '(01)00850027865010(21)0082T0196',
#        '(01)00850027865010(21)0082T0197',
#        '(01)00850027865010(21)0082T0574',
#        '(01)00850027865010(21)0082T0575',
#        '(01)00850027865010(21)0082T0005',
#        '(01)00850027865010(21)0082T0236',
#        '(01)00850027865010(21)0082T1177',
#        '(01)00850027865010(21)0082T0407',
#        '(01)00850027865010(21)0082T0843',
#        '(01)00850027865010(21)0082T0186',
#        '(01)00850027865010(21)0082T0653',
#        '(01)00850027865010(21)0082T1136',
#        '(01)00850027865010(21)0082T1137'], dtype=object)

# %%
df.tag_id.nunique()
# Out:
# 34

# %%
df.Sitio.unique()
# Out:
# array(['DC 1', 'DC 2', 'Transit', 'Store'], dtype=object)

# %%
df.zona.unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store', 'Forklift1_DC1', 'PhoneKit1GW'], dtype=object)

# %%
df.zona.nunique()
# Out:
# 15

# %%
df.groupby(['asset_id']).nunique()
# Out:
#           tipo  tag_id  Sitio  zona  device_id   hora  lat  lng  \
# asset_id
# 2            1       2      4    13         28   6769   63   63
# 37           1       2      4    14         23  12830  189  232
# 52           1       2      3    12         21   6819   53   59
# 58           1       2      3    11         19   8829  129  158
# 59           1       2      4    14         27   8823  130  158
# 62           1       2      4    13         24  11796  203  257
# 70           1       1      4    14         32   4648  160  192
# 84           1       2      3    13         23   8304  126  159
# 102          1       2      4    14         29   8197  110  132
# 145          1       2      4    13         21   4055   75   77
# 149          1       2      4    14         25   6348   59   61
# 159          1       2      4    12         25   6606  130  135
# 167          1       2      4    13         20   6774  152  178
# 170          1       2      4    14         29   6557  174  216
# 181          1       1      3    12         19   3495   33   36
# 182          1       2      3    10         23   5868   62   66
# 200          1       2      4    15         36   8112  197  240
# 205          1       2      4    15         32   5101  207  241
#
#           Temperature_C  Temperature_F
# asset_id
# 2                   238            238
# 37                  160            160
# 52                  314            314
# 58                   98             98
# 59                  338            338
# 62                  339            339
# 70                  281            281
# 84                  258            258
# 102                 406            406
# 145                  77             77
# 149                 119            119
# 159                 285            285
# 167                 408            408
# 170                 129            129
# 181                 262            262
# 182                 154            154
# 200                 102            102
# 205                 109            109

# %%
df.groupby(['asset_id'])['tag_id'].nunique()
# Out:
# asset_id
# 2      2
# 37     2
# 52     2
# 58     2
# 59     2
# 62     2
# 70     1
# 84     2
# 102    2
# 145    2
# 149    2
# 159    2
# 167    2
# 170    2
# 181    1
# 182    2
# 200    2
# 205    2
# Name: tag_id, dtype: int64

# %%
pd.DataFrame(df.groupby(['asset_id'])['tag_id'].nunique())
# Out:
#           tag_id
# asset_id
# 2              2
# 37             2
# 52             2
# 58             2
# 59             2
# 62             2
# 70             1
# 84             2
# 102            2
# 145            2
# 149            2
# 159            2
# 167            2
# 170            2
# 181            1
# 182            2
# 200            2
# 205            2

# %%
pd.DataFrame(df.groupby(['asset_id'])['tag_id'].nunique()).reset_index()
# Out:
#     asset_id  tag_id
# 0          2       2
# 1         37       2
# 2         52       2
# 3         58       2
# 4         59       2
# 5         62       2
# 6         70       1
# 7         84       2
# 8        102       2
# 9        145       2
# 10       149       2
# 11       159       2
# 12       167       2
# 13       170       2
# 14       181       1
# 15       182       2
# 16       200       2
# 17       205       2

# %%
pd.DataFrame(df.groupby(['Sitio'])['zona'].nunique()).reset_index()
# Out:
#      Sitio  zona
# 0     DC 1     5
# 1     DC 2     2
# 2    Store     4
# 3  Transit     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tipo           130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Sitio          130061 non-null  object
#  4   zona           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   hora           130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 10.9+ MB

# %%
import numpy as np

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130062 entries, 0 to 130061
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Tipo       130062 non-null  object
#  1   Asset ID   130062 non-null  object
#  2   Tag ID     130062 non-null  object
#  3   Sitio      130062 non-null  object
#  4   Zona       0 non-null       object
#  5   Device ID  130062 non-null  object
#  6   Tiempo     130062 non-null  object
#  7   lat        130062 non-null  object
#  8   Ing        130062 non-null  object
#  9   Temp_C     0 non-null       object
#  10  Temp_F     130062 non-null  object
# dtypes: object(11)
# memory usage: 10.9+ MB

# %%
df_1.loc[df_1 ['Zona'].sample(frac=2000, replace = True).index, 'Zona' ] = np.NaN
df_1

# %%
df_1.loc[df_1 ['Zona'].sample(frac=2000, replace = True).index, 'Zona' ] = np.NaN
df_1.loc[df_1 ['Temp_C'].sample(frac=1800, replace = True).index, 'Temp_C' ] = np.NaN
df_1.loc[df_1 ['Temp_F'].sample(frac=2200, replace = True).index, 'Temp_F' ] = np.NaN
df_1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-8f0c1dea6b63> in <cell line: 3>()
#       1 df_1.loc[df_1 ['Zona'].sample(frac=2000, replace = True).index, 'Zona' ] = np.NaN
#       2 df_1.loc[df_1 ['Temp_C'].sample(frac=1800, replace = True).index, 'Temp_C' ] = np.NaN
# ----> 3 df_1.loc[df_1 ['Temp_F'].sample(frac=2200, replace = True).index, 'Temp_F' ] = np.NaN
#       4 df_1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     812         else:
#     813             key = com.apply_if_callable(key, self.obj)
# --> 814         indexer = self._get_setitem_indexer(key)
#     815         self._has_valid_setitem_indexer(key)
#     816
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     695             with suppress(IndexingError):
#     696                 # suppress "Too many indexers"
# --> 697                 return self._convert_tuple(key)
#     698
#     699         if isinstance(key, range):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _convert_tuple(self, key)
#     894         # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     895         self._validate_key_length(key)
# --> 896         keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     897         return tuple(keyidx)
#     898
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in <listcomp>(.0)
#     894         # Note: we assume _tupleize_axis_indexer has been called, if necessary.
#     895         self._validate_key_length(key)
# --> 896         keyidx = [self._convert_to_indexer(k, axis=i) for i, k in enumerate(key)]
#     897         return tuple(keyidx)
#     898
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, key, axis)
#    1394                 return key
#    1395             else:
# -> 1396                 return self._get_listlike_indexer(key, axis)[1]
#    1397         else:
#    1398             try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1430         axis_name = self.obj._get_axis_name(axis)
#    1431
# -> 1432         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1433
#    1434         return keyarr, indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6063
#    6064         if self._index_as_unique:
# -> 6065             indexer = self.get_indexer_for(keyarr)
#    6066             keyarr = self.reindex(keyarr)[0]
#    6067         else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_indexer_for(self, target)
#    6050         """
#    6051         if self._index_as_unique:
# -> 6052             return self.get_indexer(target)
#    6053         indexer, _ = self.get_indexer_non_unique(target)
#    6054         return indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3971             )
#    3972
# -> 3973         return self._get_indexer(target, method, limit, tolerance)
#    3974
#    3975     def _get_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in _get_indexer(self, target, method, limit, tolerance)
#     421         locs[valid] = locs[valid] / step
#     422
# --> 423         if step != self.step:
#     424             # We reversed this range: transform to original locs
#     425             locs[valid] = len(self) - 1 - locs[valid]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in step(self)
#     291         return self.stop
#     292
# --> 293     @property
#     294     def step(self) -> int:
#     295         """
#
# KeyboardInterrupt:

# %%
df_1.info()

# %%
df_2 = df_1.fillna('NA')
df_2
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio  \
# 0       asset_type  asset_id                           tag_id   Site
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1
# ...            ...       ...                              ...    ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zona     Device ID                      Tiempo       lat  \
# 0                    Zone     device_id                    time_est       lat
# 1          dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2          dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3          dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4          dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
# ...                   ...           ...                         ...       ...
# 130057  store_front_Store  26AB1C9A2E41  2022-08-04 12:48:51.273000  47.74923
# 130058  store_front_Store  26AB1C9A2E41  2022-08-04 12:49:58.699000  47.74923
# 130059  store_front_Store  26AB1C9A2E41  2022-08-04 12:52:45.173000  47.74923
# 130060  store_front_Store  26AB1C9A2E41  2022-08-04 12:53:48.228000  47.74923
# 130061  store_front_Store  26AB1C9A2E41  2022-08-04 16:33:25.525000  47.74923
#
#              Ing         Temp_C         Temp_F
# 0            lng  Temperature_C  Temperature_F
# 1      -65.68902             23           73.4
# 2      -65.68902             23           73.4
# 3      -65.68902             23           73.4
# 4      -65.68902           23.5           74.3
# ...          ...            ...            ...
# 130057 -65.64101           23.1          73.58
# 130058 -65.64101           23.5           74.3
# 130059 -65.64101             23           73.4
# 130060 -65.64101             23           73.4
# 130061 -65.64101             24           75.2
#
# [130062 rows x 11 columns]

# %%
df_3...

# %%
df_1[df_1.Temp_C.isna()]
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio  \
# 0       asset_type  asset_id                           tag_id   Site
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1
# ...            ...       ...                              ...    ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zona     Device ID                      Tiempo       lat  \
# 0                    Zone     device_id                    time_est       lat
# 1          dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2          dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3          dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4          dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
# ...                   ...           ...                         ...       ...
# 130057  store_front_Store  26AB1C9A2E41  2022-08-04 12:48:51.273000  47.74923
# 130058  store_front_Store  26AB1C9A2E41  2022-08-04 12:49:58.699000  47.74923
# 130059  store_front_Store  26AB1C9A2E41  2022-08-04 12:52:45.173000  47.74923
# 130060  store_front_Store  26AB1C9A2E41  2022-08-04 12:53:48.228000  47.74923
# 130061  store_front_Store  26AB1C9A2E41  2022-08-04 16:33:25.525000  47.74923
#
#              Ing         Temp_C         Temp_F
# 0            lng  Temperature_C  Temperature_F
# 1      -65.68902             23           73.4
# 2      -65.68902             23           73.4
# 3      -65.68902             23           73.4
# 4      -65.68902           23.5           74.3
# ...          ...            ...            ...
# 130057 -65.64101           23.1          73.58
# 130058 -65.64101           23.5           74.3
# 130059 -65.64101             23           73.4
# 130060 -65.64101             23           73.4
# 130061 -65.64101             24           75.2
#
# [130062 rows x 11 columns]

# %%
df_4 = df_1.dropna()
df_4
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio  \
# 0       asset_type  asset_id                           tag_id   Site
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1
# ...            ...       ...                              ...    ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zona     Device ID                      Tiempo       lat  \
# 0                    Zone     device_id                    time_est       lat
# 1          dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2          dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3          dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4          dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
# ...                   ...           ...                         ...       ...
# 130057  store_front_Store  26AB1C9A2E41  2022-08-04 12:48:51.273000  47.74923
# 130058  store_front_Store  26AB1C9A2E41  2022-08-04 12:49:58.699000  47.74923
# 130059  store_front_Store  26AB1C9A2E41  2022-08-04 12:52:45.173000  47.74923
# 130060  store_front_Store  26AB1C9A2E41  2022-08-04 12:53:48.228000  47.74923
# 130061  store_front_Store  26AB1C9A2E41  2022-08-04 16:33:25.525000  47.74923
#
#              Ing         Temp_C         Temp_F
# 0            lng  Temperature_C  Temperature_F
# 1      -65.68902             23           73.4
# 2      -65.68902             23           73.4
# 3      -65.68902             23           73.4
# 4      -65.68902           23.5           74.3
# ...          ...            ...            ...
# 130057 -65.64101           23.1          73.58
# 130058 -65.64101           23.5           74.3
# 130059 -65.64101             23           73.4
# 130060 -65.64101             23           73.4
# 130061 -65.64101             24           75.2
#
# [130062 rows x 11 columns]

# %%
df_5 = df_1.dropna(subset = ['Zona'])
df_5
# Out:
#               Tipo  Asset ID                           Tag ID  Sitio  \
# 0       asset_type  asset_id                           tag_id   Site
# 1             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3             tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4             tote         2  (01)00850027865010(21)0082T0219   DC 1
# ...            ...       ...                              ...    ...
# 130057        tote       205  (01)00850027865010(21)0082T1137  Store
# 130058        tote       205  (01)00850027865010(21)0082T1137  Store
# 130059        tote       205  (01)00850027865010(21)0082T1137  Store
# 130060        tote       205  (01)00850027865010(21)0082T1137  Store
# 130061        tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zona     Device ID                      Tiempo       lat  \
# 0                    Zone     device_id                    time_est       lat
# 1          dock_doors_DC1  7F9A8353E973  2022-08-02 11:59:26.628000  47.79158
# 2          dock_doors_DC1  EC5B0499234F  2022-08-02 12:00:22.660000  47.79158
# 3          dock_doors_DC1  7F9A8353E973  2022-08-02 12:01:11.234000  47.79158
# 4          dock_doors_DC1  3D8B2BDB8673  2022-08-02 13:47:58.172000  47.79158
# ...                   ...           ...                         ...       ...
# 130057  store_front_Store  26AB1C9A2E41  2022-08-04 12:48:51.273000  47.74923
# 130058  store_front_Store  26AB1C9A2E41  2022-08-04 12:49:58.699000  47.74923
# 130059  store_front_Store  26AB1C9A2E41  2022-08-04 12:52:45.173000  47.74923
# 130060  store_front_Store  26AB1C9A2E41  2022-08-04 12:53:48.228000  47.74923
# 130061  store_front_Store  26AB1C9A2E41  2022-08-04 16:33:25.525000  47.74923
#
#              Ing         Temp_C         Temp_F
# 0            lng  Temperature_C  Temperature_F
# 1      -65.68902             23           73.4
# 2      -65.68902             23           73.4
# 3      -65.68902             23           73.4
# 4      -65.68902           23.5           74.3
# ...          ...            ...            ...
# 130057 -65.64101           23.1          73.58
# 130058 -65.64101           23.5           74.3
# 130059 -65.64101             23           73.4
# 130060 -65.64101             23           73.4
# 130061 -65.64101             24           75.2
#
# [130062 rows x 11 columns]

# %%
df_1.isnull().sum()
# Out:
# Tipo         0
# Asset ID     0
# Tag ID       0
# Sitio        0
# Zona         0
# Device ID    0
# Tiempo       0
# lat          0
# Ing          0
# Temp_C       0
# Temp_F       0
# dtype: int64

# %%
df_2 = df[df.asset_id == 2]
df_2
# Out:
#       tipo  asset_id                           tag_id  Sitio  \
# 0     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3     tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4     tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...    ...       ...                              ...    ...
# 6764  tote         2  (01)00850027865010(21)0082T0670  Store
# 6765  tote         2  (01)00850027865010(21)0082T0670  Store
# 6766  tote         2  (01)00850027865010(21)0082T0670  Store
# 6767  tote         2  (01)00850027865010(21)0082T0670  Store
# 6768  tote         2  (01)00850027865010(21)0082T0670  Store
#
#                    zona     device_id                    hora        lat  \
# 0        dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.791580
# 1        dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.791580
# 2        dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.791580
# 3        dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.791580
# 4        dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.791580
# ...                 ...           ...                     ...        ...
# 6764  store_front_Store  6AF833197EE3 2022-08-05 09:00:28.894  47.749230
# 6765  store_front_Store  6AF833197EE3 2022-08-05 09:00:50.535  47.749230
# 6766  store_front_Store  6AF833197EE3 2022-08-05 09:01:28.268  47.749230
# 6767  store_front_Store  6AF833197EE3 2022-08-05 09:02:57.199  47.749388
# 6768  store_front_Store  6AF833197EE3 2022-08-05 09:04:58.575  47.749230
#
#             lng  Temperature_C  Temperature_F
# 0    -65.689020           23.0           73.4
# 1    -65.689020           23.0           73.4
# 2    -65.689020           23.0           73.4
# 3    -65.689020           23.5           74.3
# 4    -65.689020           23.0           73.4
# ...         ...            ...            ...
# 6764 -65.641010           22.0           71.6
# 6765 -65.641010           22.0           71.6
# 6766 -65.641010           22.0           71.6
# 6767 -65.640811           22.0           71.6
# 6768 -65.641010           22.0           71.6
#
# [6769 rows x 11 columns]

# %%
df_2.asset_id.nunique()
# Out:
# 1

# %%
df_3 = df[df.asset_id.isin([2,70,205])]
df_3
# Out:
#         tipo  asset_id                           tag_id  Sitio  \
# 0       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3       tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4       tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...      ...       ...                              ...    ...
# 130056  tote       205  (01)00850027865010(21)0082T1137  Store
# 130057  tote       205  (01)00850027865010(21)0082T1137  Store
# 130058  tote       205  (01)00850027865010(21)0082T1137  Store
# 130059  tote       205  (01)00850027865010(21)0082T1137  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                    hora       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# 1          dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158
# 2          dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.79158
# 3          dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158
# 4          dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.79158
# ...                   ...           ...                     ...       ...
# 130056  store_front_Store  26AB1C9A2E41 2022-08-04 12:48:51.273  47.74923
# 130057  store_front_Store  26AB1C9A2E41 2022-08-04 12:49:58.699  47.74923
# 130058  store_front_Store  26AB1C9A2E41 2022-08-04 12:52:45.173  47.74923
# 130059  store_front_Store  26AB1C9A2E41 2022-08-04 12:53:48.228  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C  Temperature_F
# 0      -65.68902           23.0          73.40
# 1      -65.68902           23.0          73.40
# 2      -65.68902           23.0          73.40
# 3      -65.68902           23.5          74.30
# 4      -65.68902           23.0          73.40
# ...          ...            ...            ...
# 130056 -65.64101           23.1          73.58
# 130057 -65.64101           23.5          74.30
# 130058 -65.64101           23.0          73.40
# 130059 -65.64101           23.0          73.40
# 130060 -65.64101           24.0          75.20
#
# [16545 rows x 11 columns]

# %%
df_3.asset_id.nunique()
# Out:
# 3

# %%
# | = "o"
# & = "y"

df_3 = df[df.asset_id.isin([2,70,205]) & (df.Temperature_C >= 24)]
df_3
# Out:
#         tipo  asset_id                           tag_id  Sitio  \
# 5       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 6       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 7       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 8       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 9       tote         2  (01)00850027865010(21)0082T0670   DC 2
# ...      ...       ...                              ...    ...
# 129959  tote       205  (01)00850027865010(21)0082T1136  Store
# 129960  tote       205  (01)00850027865010(21)0082T1136  Store
# 129961  tote       205  (01)00850027865010(21)0082T1136  Store
# 129962  tote       205  (01)00850027865010(21)0082T1136  Store
# 130060  tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      zona     device_id                    hora       lat  \
# 5          dock_doors_DC2  379663A695EF 2022-08-03 13:22:09.038  47.79366
# 6          dock_doors_DC2  379663A695EF 2022-08-03 13:26:07.080  47.79366
# 7          dock_doors_DC2  379663A695EF 2022-08-03 10:59:28.892  47.79366
# 8          dock_doors_DC2  2FC8DD79125D 2022-08-03 12:48:11.580  47.79366
# 9          dock_doors_DC2  2FC8DD79125D 2022-08-03 13:02:29.755  47.79366
# ...                   ...           ...                     ...       ...
# 129959  store_front_Store  C8C08D22E0B1 2022-08-04 11:56:08.456  47.74923
# 129960  store_front_Store  6AF833197EE3 2022-08-04 11:58:22.995  47.74923
# 129961  store_front_Store  6AF833197EE3 2022-08-04 11:58:43.510  47.74923
# 129962  store_front_Store  6AF833197EE3 2022-08-04 11:59:14.973  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C  Temperature_F
# 5      -65.75921           25.0           77.0
# 6      -65.75921           25.0           77.0
# 7      -65.75921           24.5           76.1
# 8      -65.75921           25.0           77.0
# 9      -65.75921           25.0           77.0
# ...          ...            ...            ...
# 129959 -65.64101           24.0           75.2
# 129960 -65.64101           24.0           75.2
# 129961 -65.64101           24.0           75.2
# 129962 -65.64101           24.0           75.2
# 130060 -65.64101           24.0           75.2
#
# [9720 rows x 11 columns]

# %%
df_3.asset_id.nunique()
# Out:
# 3

# %%
df_3.Temperature_C.min()
# Out:
# 24.0

# %%
df_3 = df[(df.Sitio == 'Store') & (df.Temperature_F >= 76)]
df_3
# Out:
#         tipo  asset_id                           tag_id  Sitio  \
# 241     tote         2  (01)00850027865010(21)0082T0219  Store
# 253     tote         2  (01)00850027865010(21)0082T0219  Store
# 254     tote         2  (01)00850027865010(21)0082T0219  Store
# 255     tote         2  (01)00850027865010(21)0082T0219  Store
# 256     tote         2  (01)00850027865010(21)0082T0219  Store
# ...      ...       ...                              ...    ...
# 129516  tote       205  (01)00850027865010(21)0082T1137  Store
# 129517  tote       205  (01)00850027865010(21)0082T1137  Store
# 129518  tote       205  (01)00850027865010(21)0082T1137  Store
# 129519  tote       205  (01)00850027865010(21)0082T1137  Store
# 129935  tote       205  (01)00850027865010(21)0082T1136  Store
#
#                        zona     device_id                    hora       lat  \
# 241     point_of_sale_Store  EEEB01ADE266 2022-08-04 10:58:04.546  47.74923
# 253         receiving_Store  DC4FBAED57C9 2022-08-04 08:35:59.046  47.74923
# 254         receiving_Store  DC4FBAED57C9 2022-08-04 08:36:17.140  47.74923
# 255         receiving_Store  AC8DEAE6FD79 2022-08-04 08:37:29.468  47.74909
# 256         receiving_Store  AC8DEAE6FD79 2022-08-04 08:37:58.624  47.74923
# ...                     ...           ...                     ...       ...
# 129516     store_back_Store  58DB59BDCE08 2022-08-04 08:54:56.166  47.74923
# 129517     store_back_Store  58DB59BDCE08 2022-08-04 08:55:57.114  47.74923
# 129518     store_back_Store  58DB59BDCE08 2022-08-04 08:56:56.734  47.74923
# 129519     store_back_Store  58DB59BDCE08 2022-08-04 08:59:43.126  47.74923
# 129935    store_front_Store  6AF833197EE3 2022-08-04 10:50:26.688  47.74923
#
#              lng  Temperature_C  Temperature_F
# 241    -65.64101           24.5          76.10
# 253    -65.64101           24.5          76.10
# 254    -65.64101           24.5          76.10
# 255    -65.64076           24.5          76.10
# 256    -65.64101           24.5          76.10
# ...          ...            ...            ...
# 129516 -65.64101           28.0          82.40
# 129517 -65.64101           28.0          82.40
# 129518 -65.64101           28.0          82.40
# 129519 -65.64101           27.0          80.60
# 129935 -65.64101           25.7          78.26
#
# [70181 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tipo           130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Sitio          130061 non-null  object
#  4   zona           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   hora           130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 10.9+ MB

# %%
df_3 = df[(df.Temperature_F >= 76) & (df.Temperature_F <= 80)]
df_3
# Out:
#         tipo  asset_id                           tag_id  Sitio  \
# 5       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 6       tote         2  (01)00850027865010(21)0082T0219   DC 2
# 7       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 8       tote         2  (01)00850027865010(21)0082T0670   DC 2
# 9       tote         2  (01)00850027865010(21)0082T0670   DC 2
# ...      ...       ...                              ...    ...
# 128787  tote       205  (01)00850027865010(21)0082T1136  Store
# 128788  tote       205  (01)00850027865010(21)0082T1136  Store
# 128789  tote       205  (01)00850027865010(21)0082T1136  Store
# 128790  tote       205  (01)00850027865010(21)0082T1136  Store
# 129935  tote       205  (01)00850027865010(21)0082T1136  Store
#
#                      zona     device_id                    hora        lat  \
# 5          dock_doors_DC2  379663A695EF 2022-08-03 13:22:09.038  47.793660
# 6          dock_doors_DC2  379663A695EF 2022-08-03 13:26:07.080  47.793660
# 7          dock_doors_DC2  379663A695EF 2022-08-03 10:59:28.892  47.793660
# 8          dock_doors_DC2  2FC8DD79125D 2022-08-03 12:48:11.580  47.793660
# 9          dock_doors_DC2  2FC8DD79125D 2022-08-03 13:02:29.755  47.793660
# ...                   ...           ...                     ...        ...
# 128787   store_back_Store  F2F715EFF03F 2022-08-05 06:09:03.114  47.749230
# 128788   store_back_Store  F2F715EFF03F 2022-08-05 06:09:53.903  47.749230
# 128789   store_back_Store  F2F715EFF03F 2022-08-05 06:10:20.984  47.749230
# 128790   store_back_Store  F2F715EFF03F 2022-08-05 06:10:36.800  47.749388
# 129935  store_front_Store  6AF833197EE3 2022-08-04 10:50:26.688  47.749230
#
#               lng  Temperature_C  Temperature_F
# 5      -65.759210           25.0          77.00
# 6      -65.759210           25.0          77.00
# 7      -65.759210           24.5          76.10
# 8      -65.759210           25.0          77.00
# 9      -65.759210           25.0          77.00
# ...           ...            ...            ...
# 128787 -65.641010           24.5          76.10
# 128788 -65.641010           24.5          76.10
# 128789 -65.641010           24.5          76.10
# 128790 -65.640811           24.5          76.10
# 129935 -65.641010           25.7          78.26
#
# [51650 rows x 11 columns]

# %%
df.head()
# Out:
#   asset_type  asset_id                           tag_id  Site            Zone  \
# 0       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 1       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 2       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 3       tote         2  (01)00850027865010(21)0082T0219  DC 1  dock_doors_DC1
# 4       tote         2  (01)00850027865010(21)0082T0670  DC 1  dock_doors_DC1
#
#       device_id                time_est       lat       lng  Temperature_C  \
# 0  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
#
#    Temperature_F
# 0           73.4
# 1           73.4
# 2           73.4
# 3           74.3
# 4           73.4

# %%
df['Temperature_F'] = 0
df
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# 1          dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158
# 2          dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.79158
# 3          dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158
# 4          dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.79158
# ...                   ...           ...                     ...       ...
# 130056  store_front_Store  26AB1C9A2E41 2022-08-04 12:48:51.273  47.74923
# 130057  store_front_Store  26AB1C9A2E41 2022-08-04 12:49:58.699  47.74923
# 130058  store_front_Store  26AB1C9A2E41 2022-08-04 12:52:45.173  47.74923
# 130059  store_front_Store  26AB1C9A2E41 2022-08-04 12:53:48.228  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C  Temperature_F
# 0      -65.68902           23.0              0
# 1      -65.68902           23.0              0
# 2      -65.68902           23.0              0
# 3      -65.68902           23.5              0
# 4      -65.68902           23.0              0
# ...          ...            ...            ...
# 130056 -65.64101           23.1              0
# 130057 -65.64101           23.5              0
# 130058 -65.64101           23.0              0
# 130059 -65.64101           23.0              0
# 130060 -65.64101           24.0              0
#
# [130061 rows x 11 columns]

# %%
df['Temperature_F'] = 'NA'
df
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# 1          dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158
# 2          dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.79158
# 3          dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158
# 4          dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.79158
# ...                   ...           ...                     ...       ...
# 130056  store_front_Store  26AB1C9A2E41 2022-08-04 12:48:51.273  47.74923
# 130057  store_front_Store  26AB1C9A2E41 2022-08-04 12:49:58.699  47.74923
# 130058  store_front_Store  26AB1C9A2E41 2022-08-04 12:52:45.173  47.74923
# 130059  store_front_Store  26AB1C9A2E41 2022-08-04 12:53:48.228  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C Temperature_F
# 0      -65.68902           23.0            NA
# 1      -65.68902           23.0            NA
# 2      -65.68902           23.0            NA
# 3      -65.68902           23.5            NA
# 4      -65.68902           23.0            NA
# ...          ...            ...           ...
# 130056 -65.64101           23.1            NA
# 130057 -65.64101           23.5            NA
# 130058 -65.64101           23.0            NA
# 130059 -65.64101           23.0            NA
# 130060 -65.64101           24.0            NA
#
# [130061 rows x 11 columns]

# %%
df['Temperature_F'] = df['Temperature_C']*9/5 + 32
df
# Out:
#        asset_type  asset_id                           tag_id  \
# 0            tote         2  (01)00850027865010(21)0082T0219
# 1            tote         2  (01)00850027865010(21)0082T0219
# 2            tote         2  (01)00850027865010(21)0082T0219
# 3            tote         2  (01)00850027865010(21)0082T0219
# 4            tote         2  (01)00850027865010(21)0082T0670
# ...           ...       ...                              ...
# 130056       tote       205  (01)00850027865010(21)0082T1137
# 130057       tote       205  (01)00850027865010(21)0082T1137
# 130058       tote       205  (01)00850027865010(21)0082T1137
# 130059       tote       205  (01)00850027865010(21)0082T1137
# 130060       tote       205  (01)00850027865010(21)0082T1137
#
#                          Site               Zone     device_id  \
# 0          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# 1          [dock, doors, DC1]     dock_doors_DC1  EC5B0499234F
# 2          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# 3          [dock, doors, DC1]     dock_doors_DC1  3D8B2BDB8673
# 4          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# ...                       ...                ...           ...
# 130056  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130057  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130058  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130059  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130060  [store, front, Store]  store_front_Store  26AB1C9A2E41
#
#                       time_est       lat       lng  Temperature_C  \
# 0      2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1      2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2      2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3      2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4      2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
# ...                        ...       ...       ...            ...
# 130056 2022-08-04 12:48:51.273  47.74923 -65.64101           23.1
# 130057 2022-08-04 12:49:58.699  47.74923 -65.64101           23.5
# 130058 2022-08-04 12:52:45.173  47.74923 -65.64101           23.0
# 130059 2022-08-04 12:53:48.228  47.74923 -65.64101           23.0
# 130060 2022-08-04 16:33:25.525  47.74923 -65.64101           24.0
#
#         Temperature_F
# 0               73.40
# 1               73.40
# 2               73.40
# 3               74.30
# 4               73.40
# ...               ...
# 130056          73.58
# 130057          74.30
# 130058          73.40
# 130059          73.40
# 130060          75.20
#
# [130061 rows x 11 columns]

# %%
df['Site_1'] = df['Zone'].str.split(pat = '_')
df
# Out:
#        asset_type  asset_id                           tag_id  \
# 0            tote         2  (01)00850027865010(21)0082T0219
# 1            tote         2  (01)00850027865010(21)0082T0219
# 2            tote         2  (01)00850027865010(21)0082T0219
# 3            tote         2  (01)00850027865010(21)0082T0219
# 4            tote         2  (01)00850027865010(21)0082T0670
# ...           ...       ...                              ...
# 130056       tote       205  (01)00850027865010(21)0082T1137
# 130057       tote       205  (01)00850027865010(21)0082T1137
# 130058       tote       205  (01)00850027865010(21)0082T1137
# 130059       tote       205  (01)00850027865010(21)0082T1137
# 130060       tote       205  (01)00850027865010(21)0082T1137
#
#                          Site               Zone     device_id  \
# 0          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# 1          [dock, doors, DC1]     dock_doors_DC1  EC5B0499234F
# 2          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# 3          [dock, doors, DC1]     dock_doors_DC1  3D8B2BDB8673
# 4          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# ...                       ...                ...           ...
# 130056  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130057  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130058  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130059  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130060  [store, front, Store]  store_front_Store  26AB1C9A2E41
#
#                       time_est       lat       lng  Temperature_C  \
# 0      2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1      2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2      2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3      2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4      2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
# ...                        ...       ...       ...            ...
# 130056 2022-08-04 12:48:51.273  47.74923 -65.64101           23.1
# 130057 2022-08-04 12:49:58.699  47.74923 -65.64101           23.5
# 130058 2022-08-04 12:52:45.173  47.74923 -65.64101           23.0
# 130059 2022-08-04 12:53:48.228  47.74923 -65.64101           23.0
# 130060 2022-08-04 16:33:25.525  47.74923 -65.64101           24.0
#
#         Temperature_F                 Site_1
# 0               73.40     [dock, doors, DC1]
# 1               73.40     [dock, doors, DC1]
# 2               73.40     [dock, doors, DC1]
# 3               74.30     [dock, doors, DC1]
# 4               73.40     [dock, doors, DC1]
# ...               ...                    ...
# 130056          73.58  [store, front, Store]
# 130057          74.30  [store, front, Store]
# 130058          73.40  [store, front, Store]
# 130059          73.40  [store, front, Store]
# 130060          75.20  [store, front, Store]
#
# [130061 rows x 12 columns]

# %%
df_1 = df[df.Zone == 'dock_doors_DC1'].copy()
df_1["Site_1"] = df_1['Zone'].str.split(pat = '_', expand = True)
df_1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3e103f9e9187> in <cell line: 2>()
#       1 df_1 = df[df.Zone == 'dock_doors_DC1'].copy()
# ----> 2 df_1["Site_1"] = df_1['Zone'].str.split(pat = '_', expand = True)
#       3 df_1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
# -> 3970             self._set_item_frame_value(key, value)
#    3971         elif (
#    3972             is_list_like(value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4098             len_cols = 1 if is_scalar(cols) else len(cols)
#    4099             if len_cols != len(value.columns):
# -> 4100                 raise ValueError("Columns must be same length as key")
#    4101
#    4102             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
from datetime import datetime, date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130061 entries, 0 to 130060
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   asset_type     130061 non-null  object
#  1   asset_id       130061 non-null  int64
#  2   tag_id         130061 non-null  object
#  3   Site           130061 non-null  object
#  4   Zone           130061 non-null  object
#  5   device_id      130061 non-null  object
#  6   time_est       130061 non-null  datetime64[ns]
#  7   lat            130061 non-null  float64
#  8   lng            130061 non-null  float64
#  9   Temperature_C  130061 non-null  float64
#  10  Temperature_F  130061 non-null  float64
#  11  Site_1         130061 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(6)
# memory usage: 11.9+ MB

# %%
df.groupby(['time_est']).asset_id.unique()
# Out:
# time_est
# 2022-08-02 10:14:54.326     [70]
# 2022-08-02 10:15:38.860     [70]
# 2022-08-02 10:17:23.366     [37]
# 2022-08-02 10:18:23.847     [37]
# 2022-08-02 10:20:43.706     [37]
#                            ...
# 2022-08-05 13:28:26.584    [167]
# 2022-08-05 13:28:27.564    [200]
# 2022-08-05 13:28:28.172    [181]
# 2022-08-05 13:28:28.576     [59]
# 2022-08-05 13:28:29.966     [52]
# Name: asset_id, Length: 129887, dtype: object

# %%
df.head()
# Out:
#   asset_type  asset_id                           tag_id                Site  \
# 0       tote         2  (01)00850027865010(21)0082T0219  [dock, doors, DC1]
# 1       tote         2  (01)00850027865010(21)0082T0219  [dock, doors, DC1]
# 2       tote         2  (01)00850027865010(21)0082T0219  [dock, doors, DC1]
# 3       tote         2  (01)00850027865010(21)0082T0219  [dock, doors, DC1]
# 4       tote         2  (01)00850027865010(21)0082T0670  [dock, doors, DC1]
#
#              Zone     device_id                time_est       lat       lng  \
# 0  dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158 -65.68902
# 1  dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158 -65.68902
# 2  dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.79158 -65.68902
# 3  dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158 -65.68902
# 4  dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.79158 -65.68902
#
#    Temperature_C  Temperature_F              Site_1
# 0           23.0           73.4  [dock, doors, DC1]
# 1           23.0           73.4  [dock, doors, DC1]
# 2           23.0           73.4  [dock, doors, DC1]
# 3           23.5           74.3  [dock, doors, DC1]
# 4           23.0           73.4  [dock, doors, DC1]

# %%
df['Fecha'] = pd.to_datetime(df.time_est).dt.date
df
# Out:
#        asset_type  asset_id                           tag_id  \
# 0            tote         2  (01)00850027865010(21)0082T0219
# 1            tote         2  (01)00850027865010(21)0082T0219
# 2            tote         2  (01)00850027865010(21)0082T0219
# 3            tote         2  (01)00850027865010(21)0082T0219
# 4            tote         2  (01)00850027865010(21)0082T0670
# ...           ...       ...                              ...
# 130056       tote       205  (01)00850027865010(21)0082T1137
# 130057       tote       205  (01)00850027865010(21)0082T1137
# 130058       tote       205  (01)00850027865010(21)0082T1137
# 130059       tote       205  (01)00850027865010(21)0082T1137
# 130060       tote       205  (01)00850027865010(21)0082T1137
#
#                          Site               Zone     device_id  \
# 0          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# 1          [dock, doors, DC1]     dock_doors_DC1  EC5B0499234F
# 2          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# 3          [dock, doors, DC1]     dock_doors_DC1  3D8B2BDB8673
# 4          [dock, doors, DC1]     dock_doors_DC1  7F9A8353E973
# ...                       ...                ...           ...
# 130056  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130057  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130058  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130059  [store, front, Store]  store_front_Store  26AB1C9A2E41
# 130060  [store, front, Store]  store_front_Store  26AB1C9A2E41
#
#                       time_est       lat       lng  Temperature_C  \
# 0      2022-08-02 11:59:26.628  47.79158 -65.68902           23.0
# 1      2022-08-02 12:00:22.660  47.79158 -65.68902           23.0
# 2      2022-08-02 12:01:11.234  47.79158 -65.68902           23.0
# 3      2022-08-02 13:47:58.172  47.79158 -65.68902           23.5
# 4      2022-08-02 11:58:55.049  47.79158 -65.68902           23.0
# ...                        ...       ...       ...            ...
# 130056 2022-08-04 12:48:51.273  47.74923 -65.64101           23.1
# 130057 2022-08-04 12:49:58.699  47.74923 -65.64101           23.5
# 130058 2022-08-04 12:52:45.173  47.74923 -65.64101           23.0
# 130059 2022-08-04 12:53:48.228  47.74923 -65.64101           23.0
# 130060 2022-08-04 16:33:25.525  47.74923 -65.64101           24.0
#
#         Temperature_F                 Site_1       Fecha
# 0               73.40     [dock, doors, DC1]  2022-08-02
# 1               73.40     [dock, doors, DC1]  2022-08-02
# 2               73.40     [dock, doors, DC1]  2022-08-02
# 3               74.30     [dock, doors, DC1]  2022-08-02
# 4               73.40     [dock, doors, DC1]  2022-08-02
# ...               ...                    ...         ...
# 130056          73.58  [store, front, Store]  2022-08-04
# 130057          74.30  [store, front, Store]  2022-08-04
# 130058          73.40  [store, front, Store]  2022-08-04
# 130059          73.40  [store, front, Store]  2022-08-04
# 130060          75.20  [store, front, Store]  2022-08-04
#
# [130061 rows x 13 columns]

# %%
df.groupby(['time_est']).asset_id.unique()
# Out:
# time_est
# 2022-08-02 10:14:54.326     [70]
# 2022-08-02 10:15:38.860     [70]
# 2022-08-02 10:17:23.366     [37]
# 2022-08-02 10:18:23.847     [37]
# 2022-08-02 10:20:43.706     [37]
#                            ...
# 2022-08-05 13:28:26.584    [167]
# 2022-08-05 13:28:27.564    [200]
# 2022-08-05 13:28:28.172    [181]
# 2022-08-05 13:28:28.576     [59]
# 2022-08-05 13:28:29.966     [52]
# Name: asset_id, Length: 129887, dtype: object

# %%
df.groupby(['Fecha','Site']).asset_id.unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-6d1d98f44c42> in <cell line: 1>()
# ----> 1 df.groupby(['Site','Fecha']).asset_id.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#    1037                 return self._obj_with_exclusions
#    1038
# -> 1039             result = self._python_apply_general(
#    1040                 curried,
#    1041                 self._obj_with_exclusions,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1627             data after applying f
#    1628         """
# -> 1629         values, mutated = self.grouper.apply(f, data, self.axis)
#    1630         if not_indexed_same is None:
#    1631             not_indexed_same = mutated or self.mutated
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     825     ) -> tuple[list, bool]:
#     826         mutated = self.mutated
# --> 827         splitter = self._get_splitter(data, axis=axis)
#     828         group_keys = self.group_keys_seq
#     829         result_values = []
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_splitter(self, data, axis)
#     797         Generator yielding subsetted objects
#     798         """
# --> 799         ids, _, ngroups = self.group_info
#     800         return get_splitter(data, ids, ngroups, axis=axis)
#     801
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in group_info(self)
#     944     @cache_readonly
#     945     def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 946         comp_ids, obs_group_ids = self._get_compressed_codes()
#     947
#     948         ngroups = len(obs_group_ids)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     970         # The first returned ndarray may have any signed integer dtype
#     971         if len(self.groupings) > 1:
# --> 972             group_index = get_group_index(self.codes, self.shape, sort=True, xnull=True)
#     973             return compress_group_index(group_index, sort=self._sort)
#     974             # FIXME: compress_group_index's second return value is int64, not intp
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in codes(self)
#     895     @property
#     896     def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 897         return [ping.codes for ping in self.groupings]
#     898
#     899     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in <listcomp>(.0)
#     895     @property
#     896     def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 897         return [ping.codes for ping in self.groupings]
#     898
#     899     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in codes(self)
#     619             return self._codes
#     620
# --> 621         return self._codes_and_uniques[0]
#     622
#     623     @cache_readonly
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in _codes_and_uniques(self)
#     690             # error: Incompatible types in assignment (expression has type "Union[
#     691             # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 692             codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     693                 self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     694             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     820                 values = np.where(null_mask, na_value, values)
#     821
# --> 822         codes, uniques = factorize_array(
#     823             values,
#     824             na_sentinel=na_sentinel_arg,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     576
#     577     table = hash_klass(size_hint or len(values))
# --> 578     uniques, codes = table.factorize(
#     579         values,
#     580         na_sentinel=na_sentinel,
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df.groupby(['Fecha','Site','Zone']).asset_id.unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-0f306445163b> in <cell line: 1>()
# ----> 1 df.groupby(['Fecha','Site','Zone']).asset_id.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in wrapper(*args, **kwargs)
#    1037                 return self._obj_with_exclusions
#    1038
# -> 1039             result = self._python_apply_general(
#    1040                 curried,
#    1041                 self._obj_with_exclusions,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1627             data after applying f
#    1628         """
# -> 1629         values, mutated = self.grouper.apply(f, data, self.axis)
#    1630         if not_indexed_same is None:
#    1631             not_indexed_same = mutated or self.mutated
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     825     ) -> tuple[list, bool]:
#     826         mutated = self.mutated
# --> 827         splitter = self._get_splitter(data, axis=axis)
#     828         group_keys = self.group_keys_seq
#     829         result_values = []
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_splitter(self, data, axis)
#     797         Generator yielding subsetted objects
#     798         """
# --> 799         ids, _, ngroups = self.group_info
#     800         return get_splitter(data, ids, ngroups, axis=axis)
#     801
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in group_info(self)
#     944     @cache_readonly
#     945     def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 946         comp_ids, obs_group_ids = self._get_compressed_codes()
#     947
#     948         ngroups = len(obs_group_ids)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     970         # The first returned ndarray may have any signed integer dtype
#     971         if len(self.groupings) > 1:
# --> 972             group_index = get_group_index(self.codes, self.shape, sort=True, xnull=True)
#     973             return compress_group_index(group_index, sort=self._sort)
#     974             # FIXME: compress_group_index's second return value is int64, not intp
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in codes(self)
#     895     @property
#     896     def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 897         return [ping.codes for ping in self.groupings]
#     898
#     899     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in <listcomp>(.0)
#     895     @property
#     896     def codes(self) -> list[npt.NDArray[np.signedinteger]]:
# --> 897         return [ping.codes for ping in self.groupings]
#     898
#     899     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in codes(self)
#     619             return self._codes
#     620
# --> 621         return self._codes_and_uniques[0]
#     622
#     623     @cache_readonly
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in _codes_and_uniques(self)
#     690             # error: Incompatible types in assignment (expression has type "Union[
#     691             # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 692             codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     693                 self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     694             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     820                 values = np.where(null_mask, na_value, values)
#     821
# --> 822         codes, uniques = factorize_array(
#     823             values,
#     824             na_sentinel=na_sentinel_arg,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     576
#     577     table = hash_klass(size_hint or len(values))
# --> 578     uniques, codes = table.factorize(
#     579         values,
#     580         na_sentinel=na_sentinel,
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
pd.DataFrame(df.groupby(['Fecha','Site','Zone','asset_id']).tag_id.nunique())

# %%
df.groupby(['Fecha','Site','asset_id']).agg(temp_min = ('Temperature_C','min'), temp_max = ('Temperature_C','max') )

# %%
df.groupby(['Fecha','Site','asset_id']).agg(temp_min = ('Temperature_C','min'), temp_max = ('Temperature_C','max'), temp_avg = ('Temperature_C','mean'))
